# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame

# For Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cust_data = pd.read_csv("/Users/simranaswani/Downloads/archive-3/olist_customers_dataset.csv") 
geo_data = pd.read_csv("/Users/simranaswani/Downloads/archive-3/olist_geolocation_dataset.csv")
order_items = pd.read_csv("/Users/simranaswani/Downloads/archive-3/olist_order_items_dataset.csv")
payments_data = pd.read_csv("/Users/simranaswani/Downloads/archive-3/olist_order_payments_dataset.csv")
order_reviews=pd.read_csv("/Users/simranaswani/Downloads/archive-3/olist_order_reviews_dataset.csv")
order_data=pd.read_csv("/Users/simranaswani/Downloads/archive-3/olist_orders_dataset.csv")
sellers_data = pd.read_csv("/Users/simranaswani/Downloads/archive-3/olist_sellers_dataset.csv")

# %%
order_items = pd.read_csv("/Users/simranaswani/Downloads/archive-3/olist_order_items_dataset.csv")

# %%
products_data=pd.read_csv("/Users/simranaswani/Downloads/archive-3/olist_products_dataset.csv")

# %%
cust_data.drop(columns=['customer_unique_id']) #99441
# Out:
#                             customer_id  customer_zip_code_prefix  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7                     14409
# 1      18955e83d337fd6b2def6b18a428ac77                      9790
# 2      4e7b3e00288586ebd08712fdd0374a03                      1151
# 3      b2b6027bc5c5109e529d4dc6358b12c3                      8775
# 4      4f2d8ab171c80ec8364f7c12e35b23ad                     13056
# ...                                 ...                       ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f                      3937
# 99437  e7b71a9017aa05c9a7fd292d714858e8                      6764
# 99438  5e28dfe12db7fb50a4b2f691faecea5e                     60115
# 99439  56b18e2166679b8a959d72dd06da27f9                     92120
# 99440  274fa6071e5e17fe303b9748641082c8                      6703
#
#                customer_city customer_state
# 0                     franca             SP
# 1      sao bernardo do campo             SP
# ...

# %%
geo_data.head()#redundant
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
order_items.drop(columns=['freight_value'],inplace=True)

# %%
order_items.rename(columns = {'order_item_id':'order_item_quantity'}, inplace = True)

# %%
order_items #112650 since multiple products might be linked to one orderid
# Out:
#                                 order_id  order_item_quantity  \
# 0       00010242fe8c5a6d1ba2dd792cb16214                    1
# 1       00018f77f2f0320c557190d7a144bdd3                    1
# 2       000229ec398224ef6ca0657da4fc703e                    1
# 3       00024acbcdf0a6daa1e931b038114c75                    1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9                    1
# ...                                  ...                  ...
# 112645  fffc94f6ce00a00581880bf54a75a037                    1
# 112646  fffcd46ef2263f404302a634eb57f7eb                    1
# 112647  fffce4705a9662cd70adb13d4a31832d                    1
# 112648  fffe18544ffabc95dfada21779c9644f                    1
# 112649  fffe41c64501cc87c801fd61db3f6244                    1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# ...

# %%
 payments_data.drop(columns=['payment_sequential']) #103886 since some might have multiple installments
# Out:
#                                 order_id payment_type  payment_installments  \
# 0       b81ef226f3fe1789b1e8b2acac839d17  credit_card                     8
# 1       a9810da82917af2d9aefd1278f1dcfa0  credit_card                     1
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd  credit_card                     1
# 3       ba78997921bbcdc1373bb41e913ab953  credit_card                     8
# 4       42fdf880ba16b47b59251dd489d4441a  credit_card                     2
# ...                                  ...          ...                   ...
# 103881  0406037ad97740d563a178ecc7a2075c       boleto                     1
# 103882  7b905861d7c825891d6347454ea7863f  credit_card                     2
# 103883  32609bbb3dd69b3c066a6860554a77bf  credit_card                     1
# 103884  b8b61059626efa996a60be9bb9320e10  credit_card                     5
# 103885  28bbae6599b09d39ca406b747b6632b1       boleto                     1
#
#         payment_value
# 0               99.33
# ...

# %%
payments_data[payments_data['payment_sequential']>1].count()
# Out:
# order_id                4526
# payment_sequential      4526
# payment_type            4526
# payment_installments    4526
# payment_value           4526
# dtype: int64

# %%
order_reviews.head()
order_reviews['review_creation_date']=pd.to_datetime(order_reviews['review_creation_date'])
order_reviews['review_creation_date']= order_reviews['review_creation_date'].dt.date

# %%
order_reviews['review_answer_timestamp']=pd.to_datetime(order_reviews['review_answer_timestamp'])
order_reviews['review_answer_timestamp']=order_reviews['review_answer_timestamp'].dt.date

# %%
order_reviews.drop(columns=['review_comment_title','review_comment_message'],inplace=True)#99224

# %%
order_reviews.rename(columns = {'review_creation_date':'review_form_sent_on'}, inplace = True)

# %%
order_reviews
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_form_sent_on review_answer_timestamp
# ...

# %%
products_data.drop(columns=['product_name_lenght','product_length_cm','product_height_cm','product_width_cm'],inplace=True)

# %%
translation=pd.read_csv("/Users/simranaswani/Downloads/archive-3/product_category_name_translation.csv")
products_data =pd.merge(products_data,translation,on='product_category_name')
products_data
# Out:
#                              product_id      product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                 perfumaria
# 1      6a2fb4dd53d2cdb88e0432f1284a004c                 perfumaria
# 2      0d009643171aee696f4733340bc2fdd0                 perfumaria
# 3      b1eae565a61935e0011ee7682fef9dc9                 perfumaria
# 4      8da90b37f0fb171b4877c124f965b1f6                 perfumaria
# ...                                 ...                        ...
# 32323  13b25797ad1e6d6c7cd3cbeb35f8ee7a  moveis_colchao_e_estofado
# 32324  dc36a7859b743d8610a2bbbaea26ece9  moveis_colchao_e_estofado
# 32325  107fde0930956120d1e13dd1062fbb46  moveis_colchao_e_estofado
# 32326  726b4e18f00255e2e63491bcba3f60b8  moveis_colchao_e_estofado
# 32327  1dceebcc5f23c02ea23e16d5bedca000          cds_dvds_musicais
#
#        product_description_lenght  product_photos_qty  product_weight_g  \
# 0                           287.0                 1.0             225.0
# ...

# %%
products_data['product_category_name']= products_data['product_category_name_english']
products_data.drop(columns=['product_category_name_english'],inplace=True)

# %%
products_data
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                          perfumery
# 1      6a2fb4dd53d2cdb88e0432f1284a004c                          perfumery
# 2      0d009643171aee696f4733340bc2fdd0                          perfumery
# 3      b1eae565a61935e0011ee7682fef9dc9                          perfumery
# 4      8da90b37f0fb171b4877c124f965b1f6                          perfumery
# ...                                 ...                                ...
# 32323  13b25797ad1e6d6c7cd3cbeb35f8ee7a  furniture_mattress_and_upholstery
# 32324  dc36a7859b743d8610a2bbbaea26ece9  furniture_mattress_and_upholstery
# 32325  107fde0930956120d1e13dd1062fbb46  furniture_mattress_and_upholstery
# 32326  726b4e18f00255e2e63491bcba3f60b8  furniture_mattress_and_upholstery
# 32327  1dceebcc5f23c02ea23e16d5bedca000                  cds_dvds_musicals
#
# ...

# %%
order_data.drop(columns=['order_approved_at','order_delivered_carrier_date'],inplace=True)

# %%
order_data['order_purchase_timestamp']=pd.to_datetime(order_data['order_purchase_timestamp'])
order_data['order_purchase_timestamp']= order_data['order_purchase_timestamp'].dt.date
order_data['order_delivered_customer_date']=pd.to_datetime(order_data['order_delivered_customer_date'])
order_data['order_delivered_customer_date']= order_data['order_delivered_customer_date'].dt.date
order_data['order_estimated_delivery_date']=pd.to_datetime(order_data['order_estimated_delivery_date'])
order_data['order_estimated_delivery_date']= order_data['order_estimated_delivery_date'].dt.date
order_data['diff_bet_estimated_&_actual'] = order_data['order_estimated_delivery_date']-order_data['order_delivered_customer_date']

# %%
order_data #99441
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp order_delivered_customer_date  \
# ...

# %%
#finding the category which is the most popular/has the max orders 
order_items=pd.merge(order_items,products_data,on='product_id',how='left')
order_items['order_id'].nunique()
# Out:
# 98666

# %%
#order_data['product_id'].mode()

# %%
order_items['shipping_limit_date']=pd.to_datetime(order_items['shipping_limit_date'])
order_items['shipping_limit_date']= order_items['shipping_limit_date'].dt.date

# %%
order_items.mode()
# Out:
#                            order_id  order_item_quantity  \
# 0  8272b63d03f5f79c56e9e4120aec44ef                    1
#
#                          product_id                         seller_id  \
# 0  aca2eb7d00ea1a7b8ebd4e68314663af  6560211a19b47992c3666cc44a7e94c0
#
#   shipping_limit_date  price product_category_name  \
# 0          2017-11-30   59.9        bed_bath_table
#
#    product_description_lenght  product_photos_qty  product_weight_g
# 0                       341.0                 1.0             200.0

# %%
#sns.heatmap(order_items[['product_category_name','price']])


count = order_items.groupby('product_category_name')['order_id'].count()
categories = order_items['product_category_name'].unique()
df_count = pd.DataFrame(count)
df_categories=pd.DataFrame(categories)

# %%
order_items #link product_id	 with order id to check how many time order has been made for the product (can link with price )
# Out:
#                                 order_id  order_item_quantity  \
# 0       00010242fe8c5a6d1ba2dd792cb16214                    1
# 1       00018f77f2f0320c557190d7a144bdd3                    1
# 2       000229ec398224ef6ca0657da4fc703e                    1
# 3       00024acbcdf0a6daa1e931b038114c75                    1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9                    1
# ...                                  ...                  ...
# 112645  fffc94f6ce00a00581880bf54a75a037                    1
# 112646  fffcd46ef2263f404302a634eb57f7eb                    1
# 112647  fffce4705a9662cd70adb13d4a31832d                    1
# 112648  fffe18544ffabc95dfada21779c9644f                    1
# 112649  fffe41c64501cc87c801fd61db3f6244                    1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# ...

# %%
df_count.dropna()
# Out:
#                             order_id
# product_category_name
# agro_industry_and_commerce       212
# air_conditioning                 297
# art                              209
# arts_and_craftmanship             24
# audio                            364
# ...                              ...
# stationery                      2517
# tablets_printing_image            83
# telephony                       4545
# toys                            4117
# watches_gifts                   5991
#
# [71 rows x 1 columns]

# %%
df_count.sort_values(by='order_id',ascending=False,inplace=True)

# %%
#Represenation of the highest selling product categories

df_count.head(10).plot.barh()
# Out:
# <Axes: ylabel='product_category_name'>

# %%
price=pd.DataFrame(order_items.groupby('product_category_name')['price'].agg(np.mean))
df_count=pd.merge(df_count,price,how='inner',left_on=['product_category_name'],right_on=['product_category_name'])
df_count
# Out:
#                            order_id       price
# product_category_name
# bed_bath_table                11115   93.296327
# health_beauty                  9670  130.163531
# sports_leisure                 8641  114.344285
# furniture_decor                8334   87.564494
# computers_accessories          7827  116.513903
# ...                             ...         ...
# arts_and_craftmanship            24   75.583750
# la_cuisine                       14  146.785000
# cds_dvds_musicals                14   52.142857
# fashion_childrens_clothes         8   71.231250
# security_and_services             2  141.645000
#
# [71 rows x 2 columns]

# %%
df_count.rename(columns={'order_id':'quantity','price':'avg_price'},inplace=True)

# %%
df_count.rename(columns={'quantity':'quantity_of_orders'},inplace=True)

# %%
df_count.columns = ['quantity_of_orders','avg_price']

# %%
df_count
# Out:
#                            quantity_of_orders   avg_price
# product_category_name
# bed_bath_table                          11115   93.296327
# health_beauty                            9670  130.163531
# sports_leisure                           8641  114.344285
# furniture_decor                          8334   87.564494
# computers_accessories                    7827  116.513903
# ...                                       ...         ...
# arts_and_craftmanship                      24   75.583750
# la_cuisine                                 14  146.785000
# cds_dvds_musicals                          14   52.142857
# fashion_childrens_clothes                   8   71.231250
# security_and_services                       2  141.645000
#
# [71 rows x 2 columns]

# %%
order_data = pd.merge(order_data,cust_data[['customer_id','customer_zip_code_prefix','customer_state']],on='customer_id',how='inner')

# %%
order_data
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp order_delivered_customer_date  \
# ...

# %%
#Max orders state wise 
df_state=pd.DataFrame(order_data.groupby('customer_state')['order_id'].count().reset_index())
df_state.sort_values(by='order_id',ascending=False)
df_state.rename(columns={'order_id':'order_per_state'},inplace=True)

# %%
#plot this on a map
df_state
# Out:
#    customer_state  order_per_state
# 0              AC               81
# 1              AL              413
# 2              AM              148
# 3              AP               68
# 4              BA             3380
# 5              CE             1336
# 6              DF             2140
# 7              ES             2033
# 8              GO             2020
# 9              MA              747
# 10             MG            11635
# 11             MS              715
# 12             MT              907
# 13             PA              975
# 14             PB              536
# 15             PE             1652
# 16             PI              495
# 17             PR             5045
# 18             RJ            12852
# 19             RN              485
# 20             RO              253
# 21             RR               46
# 22             RS             5466
# 23             SC             3637
# 24             SE              350
# 25             SP            41746
# ...

# %%
payments_data
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value
# ...

# %%
order_items =pd.merge(order_items,payments_data[['order_id','payment_type','payment_value']],on='order_id')

# %%
#Most used payment type
df_payments=pd.DataFrame(order_items.groupby('payment_type')['order_id'].count().reset_index())
df_payments.sort_values(by='order_id',ascending=False)
df_payments
# Out:
#   payment_type  order_id
# 0       boleto     22867
# 1  credit_card     86769
# 2   debit_card      1691
# 3      voucher      6274

# %%
order_items
# Out:
#                                 order_id  order_item_quantity  \
# 0       00010242fe8c5a6d1ba2dd792cb16214                    1
# 1       00018f77f2f0320c557190d7a144bdd3                    1
# 2       000229ec398224ef6ca0657da4fc703e                    1
# 3       00024acbcdf0a6daa1e931b038114c75                    1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9                    1
# ...                                  ...                  ...
# 117596  fffc94f6ce00a00581880bf54a75a037                    1
# 117597  fffcd46ef2263f404302a634eb57f7eb                    1
# 117598  fffce4705a9662cd70adb13d4a31832d                    1
# 117599  fffe18544ffabc95dfada21779c9644f                    1
# 117600  fffe41c64501cc87c801fd61db3f6244                    1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# ...

# %%
df_payments_data = order_items[['order_id','payment_type','product_category_name']]
df_payments_cat=pd.DataFrame(df_payments_data.groupby(['product_category_name', 'payment_type']).size().reset_index(name='count'))
df_payments_cat.sort_values(by='product_category_name',ascending=False)
df_payments_cat #user PowerBI to plot
# Out:
#           product_category_name payment_type  count
# 0    agro_industry_and_commerce       boleto     60
# 1    agro_industry_and_commerce  credit_card    145
# 2    agro_industry_and_commerce   debit_card      5
# 3    agro_industry_and_commerce      voucher     42
# 4              air_conditioning       boleto     69
# ..                          ...          ...    ...
# 258                        toys      voucher    199
# 259               watches_gifts       boleto   1025
# 260               watches_gifts  credit_card   4858
# 261               watches_gifts   debit_card     63
# 262               watches_gifts      voucher    255
#
# [263 rows x 3 columns]

# %%
#prodid and orderid mapping to check how many orders were created for a specific product
df_dups=pd.DataFrame(order_items.pivot_table(index = ['product_id'], aggfunc ='size').reset_index() )
df_dups.rename(columns={0:'no_of_orders'},inplace=True)

# %%
df_dups.sort_values(by='no_of_orders',ascending=False,inplace=True)
#df_dups=pd.merge(df_dups,order_items[['product_id','product_category_name','price']],on='product_id')

# %%
df_prod =order_items[['product_id','price']]
df_prod = df_prod.groupby('product_id')['price'].mean().reset_index()
df_prod
df_dups=pd.merge(df_dups,df_prod,on='product_id')

# %%
df_dups
# Out:
#                              product_id  no_of_orders       price
# 0      aca2eb7d00ea1a7b8ebd4e68314663af           536   71.358582
# 1      99a4788cb24856965c36a24e339b6058           525   88.207543
# 2      422879e10f46682990de24d770e7f83d           505   54.841228
# 3      389d119b48cf3043d311335e499d9c6b           406   54.633473
# 4      368c6c730842d78016ad823897a372db           395   54.246582
# ...                                 ...           ...         ...
# 32946  6e110609c2314bbd56666eb2cdb464b3             1   85.990000
# 32947  6dffbeaccacce13f3812c3cfea13ad7b             1  170.900000
# 32948  6dff489dd40cf8c8575c6ac85b080f04             1   69.900000
# 32949  6dfe5ffea29ecbbe138a4066b5ebec9b             1   79.900000
# 32950  fffe9eeff12fcbd74a2f2b007dde0c58             1  249.990000
#
# [32951 rows x 3 columns]

# %%
df_cat =order_items[['product_id','product_category_name']]
df_cat = df_cat.drop_duplicates()
df_dups=pd.merge(df_dups,df_cat,on='product_id')

# %%
df_dups['no_of_orders'].sum() #no of orders for each product and the avg price for the product
# Out:
# 117601

# %%
#for each product id we have the number of orders. However we dont know at what price those orders were placed
df_prod1=order_items[['product_id','price']]
df_prod1=df_prod1.groupby('product_id')['price'].unique().reset_index()
df_prod1
df_prod2order_items[['product_id','price']]
#df_dups1=pd.merge(df_dups,df_prod,on='product_id')

# %%
df_prod1
# Out:
#                              product_id             price
# 0      00066f42aeeb9f3007548bb9d3f33c38          [101.65]
# 1      00088930e925c41fd95ebfe695fd2655           [129.9]
# 2      0009406fd7479715e4bef61dd91f2462           [229.0]
# 3      000b8f95fcb9e0096488278317764d19            [58.9]
# 4      000d9be29b5207b54e86aa1b1ac54872           [199.0]
# ...                                 ...               ...
# 32946  fff6177642830a9a94a0f2cba5e476d1  [119.99, 109.99]
# 32947  fff81cc3158d2725c0655ab9ba0f712c            [90.0]
# 32948  fff9553ac224cec9d15d49f5a263411f            [32.0]
# 32949  fffdb2d0ec8d6a61f0a0a0db3f25b441    [34.99, 29.99]
# 32950  fffe9eeff12fcbd74a2f2b007dde0c58          [249.99]
#
# [32951 rows x 2 columns]

# %%
df_dups2=pd.DataFrame(order_items.pivot_table(index = ['product_id'], aggfunc ='size').reset_index())
df_dups2

merged_table = pd.merge(order_items[['product_id','price']].explode('price'),order_items[['product_id','price','order_id']], on=['product_id','price'])
merged_table = merged_table.drop_duplicates()
merged_table
order_counts = merged_table.groupby(['product_id', 'price']).size().reset_index()
order_counts.rename(columns={0:'No_of_orders'},inplace=True)
order_counts.sort_values(by='No_of_orders',ascending=False)
order_counts['No_of_orders'].sum()
# Out:
# 102424

# %%
order_counts.sort_values(by='order_count',ascending=False)
order_counts
# Out:
#                              product_id   price  order_count
# 0      00066f42aeeb9f3007548bb9d3f33c38  101.65            1
# 1      00088930e925c41fd95ebfe695fd2655  129.90            1
# 2      0009406fd7479715e4bef61dd91f2462  229.00            1
# 3      000b8f95fcb9e0096488278317764d19   58.90            2
# 4      000d9be29b5207b54e86aa1b1ac54872  199.00            1
# ...                                 ...     ...          ...
# 42402  fff81cc3158d2725c0655ab9ba0f712c   90.00            1
# 42403  fff9553ac224cec9d15d49f5a263411f   32.00            1
# 42404  fffdb2d0ec8d6a61f0a0a0db3f25b441   29.99            1
# 42405  fffdb2d0ec8d6a61f0a0a0db3f25b441   34.99            4
# 42406  fffe9eeff12fcbd74a2f2b007dde0c58  249.99            1
#
# [42407 rows x 3 columns]

# %%
hi = order_items[['product_id','price']].explode('price')
hi.drop_duplicates().reset_index()
# Out:
#         index                        product_id   price
# 0           0  4244733e06e7ecb4970a6e2683c13e61   58.90
# 1           1  e5f2d52b802189ee658865ca93d83a8f  239.90
# 2           2  c777355d18b72b67abbeef9df44fd0fd  199.00
# 3           3  7634da152a4610f1595efa32f14722fc   12.99
# 4           4  ac6c3623068f30de03045865e4e10089  199.90
# ...       ...                               ...     ...
# 42402  117576  2e910736c31392d46841f315e9511405   65.99
# 42403  117583  dd469c03ad67e201bc2179ef077dcd48  736.00
# 42404  117588  bbe7651fef80287a816ead73f065fc4b  229.90
# 42405  117597  32e07fd915822b0765e448c4dd74c828  350.00
# 42406  117600  350688d9dc1e75ff97be326363655e01   43.00
#
# [42407 rows x 3 columns]

# %%
df_prod22 =order_items[['product_id','price']]
df_prod22 = df_prod22.groupby('product_id')['price'].size().reset_index()
df_prod22.sort_values(by='price',ascending=False)
# Out:
#                              product_id  price
# 0      00066f42aeeb9f3007548bb9d3f33c38      1
# 1      00088930e925c41fd95ebfe695fd2655      1
# 2      0009406fd7479715e4bef61dd91f2462      1
# 3      000b8f95fcb9e0096488278317764d19      2
# 4      000d9be29b5207b54e86aa1b1ac54872      1
# ...                                 ...    ...
# 32946  fff6177642830a9a94a0f2cba5e476d1      2
# 32947  fff81cc3158d2725c0655ab9ba0f712c      1
# 32948  fff9553ac224cec9d15d49f5a263411f      1
# 32949  fffdb2d0ec8d6a61f0a0a0db3f25b441      5
# 32950  fffe9eeff12fcbd74a2f2b007dde0c58      1
#
# [32951 rows x 2 columns]

# %%
orders_by_prod = order_items[['product_id','price','order_id']].groupby("product_id")["order_id"].nunique().rename("Order_count").reset_index()
table3 = pd.merge(order_items[['product_id','price']], orders_by_prod, on="product_id", how="left")
table3["Order_count"] = table3["Order_count"].fillna(0)
table3.sort_values(by='Order_count',ascending=False)
table3["Order_count"].sum()
orders_by_prod
# Out:
#                              product_id  Order_count
# 0      00066f42aeeb9f3007548bb9d3f33c38            1
# 1      00088930e925c41fd95ebfe695fd2655            1
# 2      0009406fd7479715e4bef61dd91f2462            1
# 3      000b8f95fcb9e0096488278317764d19            2
# 4      000d9be29b5207b54e86aa1b1ac54872            1
# ...                                 ...          ...
# 32946  fff6177642830a9a94a0f2cba5e476d1            2
# 32947  fff81cc3158d2725c0655ab9ba0f712c            1
# 32948  fff9553ac224cec9d15d49f5a263411f            1
# 32949  fffdb2d0ec8d6a61f0a0a0db3f25b441            5
# 32950  fffe9eeff12fcbd74a2f2b007dde0c58            1
#
# [32951 rows x 2 columns]

# %%
table1 =order_items[['product_id','price','order_id']]
table1_gp = table1.groupby(['product_id', 'price'], as_index=False)['order_id'].count()
table2 = order_items[['product_id','price']]
hi = table2.merge(table1_gp, on=['product_id','price']).rename(columns={'order_id': 'Order_Count'})
hi.drop_duplicates(inplace=True)
hi
# Out:
#                               product_id   price  Order_Count
# 0       4244733e06e7ecb4970a6e2683c13e61   58.90            4
# 4       e5f2d52b802189ee658865ca93d83a8f  239.90            1
# 5       c777355d18b72b67abbeef9df44fd0fd  199.00            3
# 8       7634da152a4610f1595efa32f14722fc   12.99            2
# 10      ac6c3623068f30de03045865e4e10089  199.90            9
# ...                                  ...     ...          ...
# 117596  2e910736c31392d46841f315e9511405   65.99            1
# 117597  dd469c03ad67e201bc2179ef077dcd48  736.00            1
# 117598  bbe7651fef80287a816ead73f065fc4b  229.90            1
# 117599  32e07fd915822b0765e448c4dd74c828  350.00            1
# 117600  350688d9dc1e75ff97be326363655e01   43.00            1
#
# [42407 rows x 3 columns]
